# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\DELL_INSPIRON\OneDrive\Desktop\Amazon_Sale_Report.csv" ,encoding="ISO-8859-1")

# %%
data.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
data.shape
# Out:
# (128976, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
data.describe()
# Out:
#                index            Qty         Amount  ship-postal-code  New  \
# count  128976.000000  128976.000000  121176.000000     128941.000000  0.0
# mean    64486.130427       0.904401     648.562176     463945.677744  NaN
# std     37232.897832       0.313368     281.185041     191458.488954  NaN
# min         0.000000       0.000000       0.000000     110001.000000  NaN
# 25%     32242.750000       1.000000     449.000000     382421.000000  NaN
# 50%     64486.500000       1.000000     605.000000     500033.000000  NaN
# 75%     96730.250000       1.000000     788.000000     600024.000000  NaN
# max    128974.000000      15.000000    5584.000000     989898.000000  NaN
#
#        PendingS
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
data.isna().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
data = data.drop(['New','PendingS'],axis=1)

# %%
data.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
import seaborn as sns

# %%
a_df = sns.countplot(x='Size' ,data=data)
for bar in a_df.containers:
    a_df.bar_label(bar)

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
data.groupby(['Size'],as_index=False)['Qty'].sum().sort_values(by='Qty', ascending=0)
# Out:
#     Size    Qty
# 6      M  20138
# 5      L  19706
# 8     XL  18636
# 10   XXL  16246
# 7      S  15041
# 0    3XL  13360
# 9     XS   9850
# 4   Free   2070
# 3    6XL    688
# 2    5XL    513
# 1    4XL    398

# %%
data.groupby(['Category'] , as_index=False)['Qty'].sum().sort_values(by='Qty' , ascending=0)
# Out:
#    Category    Qty
# 5   T-shirt  45292
# 2     Shirt  45044
# 0   Blazzer  13943
# 6  Trousers   9898
# 1   Perfume   1051
# 7    Wallet    863
# 4     Socks    399
# 3     Shoes    153
# 8     Watch      3

# %%
df=sns.countplot(data=data,x='Category')
for bar in df.containers:
    df.bar_label(bar)

plt.xticks(rotation=90)

plt.show()

# %%
data.groupby(['ship-state'], as_index=False)['Qty'].sum().sort_values(by = 'Qty',ascending=False)
# Out:
#        ship-state    Qty
# 28    MAHARASHTRA  20338
# 23      KARNATAKA  15901
# 56     TAMIL NADU  10416
# 57      TELANGANA  10253
# 59  UTTAR PRADESH   9507
# ..            ...    ...
# 37       Nagaland      1
# 3              AR      1
# 68       rajsthan      1
# 33      Meghalaya      0
# 2             APO      0
#
# [69 rows x 2 columns]

# %%
data['ship-state'].value_counts()
# Out:
# MAHARASHTRA               22272
# KARNATAKA                 17324
# TAMIL NADU                11488
# TELANGANA                 11330
# UTTAR PRADESH             10646
#                           ...
# Mizoram                       1
# rajsthan                      1
# Punjab/Mohali/Zirakpur        1
# Rajsthan                      1
# orissa                        1
# Name: ship-state, Length: 69, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=data, x='ship-state')
plt.xlabel('ship-state')
plt.ylabel('count')
plt.title('distribution of state')
plt.xticks(rotation=90)
plt.show()

# %%
df=data[data['ship-state']=='MAHARASHTRA'].groupby('ship-city')['Qty'].sum().sort_values(ascending=False).reset_index().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x='ship-city',y='Qty', data=df)
plt.xlabel('City')
plt.ylabel('Total Quantity')
plt.title('Top 10 Cities in Maharashtra by Total Quantity Ordered')
plt.xticks(rotation=80, ha='right')

plt.show()

# %%
data['B2B'].value_counts()
# Out:
# False    128104
# True        872
# Name: B2B, dtype: int64

# %%
plt.pie(data['B2B'].value_counts(),labels=data['B2B'].value_counts(),autopct='%1.1f%%')
plt.title("B2B Sales")
plt.show()

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
data['fulfilled-by'].value_counts()
# Out:
# Easy Ship    39263
# Name: fulfilled-by, dtype: int64

# %%
plt.pie(data['fulfilled-by'].value_counts(),labels=['Easy_ship'],autopct='%1.1f%%')
plt.title('How much sale easy-ship')
plt.show()

# %%
data['Sales Channel'].value_counts()
# Out:
# Amazon.in     128852
# Non-Amazon       124
# Name: Sales Channel, dtype: int64

# %%
plt.pie(data['Sales Channel'].value_counts(),labels=['Amazon','Non-Amazon'],autopct='%1.1f%%',colors=['magenta','black'])
plt.title('Amazon sales')
plt.show()

# %%
data['Status'].value_counts()
# Out:
# Shipped                          77815
# Shipped - Delivered to Buyer     28756
# Cancelled                        18334
# Shipped - Returned to Seller      1954
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: Status, dtype: int64

# %%
data.groupby('Status')['Qty'].sum().sort_values(ascending=False)
# Out:
# Status
# Shipped                          78020
# Shipped - Delivered to Buyer     28872
# Cancelled                         5656
# Shipped - Returned to Seller      1971
# Shipped - Picked Up                977
# Pending                            657
# Pending - Waiting for Pick Up      283
# Shipped - Returning to Seller      150
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: Qty, dtype: int64

# %%
sns.countplot(data=data, x='Status' )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Conclusion:
# We can see in above Data Visual-graphs that most of the buyer are from Maharastra , and Tshirt & Shirt are highest demanded Products and  blazers & troussers are in demand after those . you should focus on those item's supply.
